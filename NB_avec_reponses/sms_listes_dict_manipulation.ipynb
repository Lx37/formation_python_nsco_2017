# %% [markdown]
# Exercice : Traduire un SMS en langage ado
# A partir du fichier sms.txt créer un dictionnaire
#
# Traduisez ensuite un message en francais en langage sms
#
# Pensez à supprimez les espaces pour traduire,
# et à les remettre pour afficher la traduction :-)

# %%
f=open("/Users/admin/Desktop/sms.txt","r")
dico={}
newph=[]
l=f.readlines()
for el in l:
    defs=el.split(":")
    dico[defs[0]]=defs[1][:-1]
ph=input("phrase a traduire ?")
ph=ph.split(" ")
for el in ph:
    newph.append(dico[el])
newph=" ".join(newph)
print(newph)
# Out:
# phrase a traduire ?coucou
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-35c9f5cc8375> in <module>()
#       9 ph=ph.split(" ")
#      10 for el in ph:
# ---> 11     newph.append(dico[el])
#      12 newph=" ".join(newph)
#      13 print(newph)
#
# KeyError: 'coucou'
