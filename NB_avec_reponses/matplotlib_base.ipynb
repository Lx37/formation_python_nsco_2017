# %% [markdown]
# # Sequence 7 : matplotlib

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.array([3., 5.6,3.3, 4.5,])

# %%
plt.plot(a)

# %% [markdown]
# # Il faut avoir une approche objet!!
#
# De mieux choisir explicitement, si on tarce 2 courbes sur 2 figures ou sur une seule.

# %%
fig, ax = plt.subplots()
print(type(fig))
print(type(ax))
ax.plot(a)
ax.plot(a**2, color='r')
ax.set_title('weigth evolution')
ax.set_xlabel('age')
ax.set_ylabel('weigth')
# Out:
# <class 'matplotlib.figure.Figure'>
# <class 'matplotlib.axes._subplots.AxesSubplot'>

# %% [markdown]
# Celà permet aussi de générer une grille de subplot.

# %%
#TODO on fait une grille
fig, axs = plt.subplots(nrows = 2, ncols=3)
for r in range(2):
    for c in range(3):
        ax = axs[r,c]
        ax.plot(np.random.rand(5))
        ax.set_title('row{} col{}'.format(r,c))
        ax.set_xticks([])
        ax.set_yticks([])
fig.savefig('mafigure.png')

# %% [markdown]
# # 2 variables

# %%
fig, ax = plt.subplots()
a = np.array([1, 1.4, 5, 6.3])
w = np.array([10, 15.3, 24, 50.])
w2 = w[::-1]
ax.plot(a, w, marker='o', linestyle='--', color='m', markerfacecolor='#FF8000', label='animal1')
ax.plot(a, w2, marker='*', linestyle='--', color='g', markerfacecolor='#C280FF', label='animal2')
ax.set_title('weight evolution')
ax.set_xlabel('age')
ax.set_ylabel('weight')
ax.set_xlim(0,10)
ax.set_ylim(0,100)
ax.legend()

# %% [markdown]
#  # scatter plot
#  pour un nuage de point c'est identique mais sauf le line style

# %%
fig, ax = plt.subplots()
x = np.random.randn(200)*2+5
y = np.random.randn(200)/2+2
ax.plot(x, y, marker='o', linestyle='None', )

# %% [markdown]
# # Excercice 7.1
#
#
# Créer un signal sinusoidal de frequence 5Hz entre 0 et 3.s.
#
# Aide : il faut créer un vecteur **temps**
#
# frequence echantillonage de 1000Hz

# %% [markdown]
# # Solution 7.1

# %%
sampling_rate = 1000.
freq = 5.
times = np.arange(0,3, 1./sampling_rate)
sig = np.sin(np.pi*2*freq*times)
fig, ax = plt.subplots()
ax.plot(times, sig)

# %% [markdown]
# # exercice 7.2
#
# Idem mais avec du bruit blanc.

# %% [markdown]
# # Solution 7.2

# %%
sampling_rate = 1000.
freq = 5.
times = np.arange(0,3, 1./sampling_rate)
sig = np.sin(np.pi*2*freq*times)
noise = np.random.randn(sig.size)*.3
sig = sig + noise
fig, ax = plt.subplots()
ax.plot(times, sig)

# %% [markdown]
# # histogram
# numpy propose une fonction histogram qui renvois count, bins.
# Attention le vecteur bins correspond au limites de bins donc count.size = bins.size - 1

# %%
#TODO detail du count
a = np.concatenate([np.random.randn(1000)*.2-.4, np.random.randn(4000)+1.6])
bins = np.arange(-1, 1, .1)
count, bins = np.histogram(a, bins=bins)
fig, ax = plt.subplots()
ax.bar(bins[:-1],count,width=.1)
# Out:
# <Container object of 19 artists>

# %%
#plus simplement
fig, ax = plt.subplots()
ax.hist(a, bins=50)
# Out:
# (array([   2.,    2.,    3.,    6.,    7.,    8.,   37.,  132.,  259.,
#          323.,  231.,  124.,   91.,   74.,   89.,  124.,  139.,  144.,
#          163.,  170.,  185.,  217.,  222.,  249.,  233.,  199.,  200.,
#          195.,  202.,  159.,  143.,  124.,  129.,   89.,   82.,   73.,
#           41.,   33.,   30.,   18.,   25.,    6.,    8.,    2.,    2.,
#            4.,    0.,    1.,    0.,    1.]),
#  array([-1.71239124, -1.57430559, -1.43621994, -1.29813429, -1.16004864,
#         -1.021963  , -0.88387735, -0.7457917 , -0.60770605, -0.4696204 ,
#         -0.33153475, -0.1934491 , -0.05536345,  0.08272219,  0.22080784,
#          0.35889349,  0.49697914,  0.63506479,  0.77315044,  0.91123609,
#          1.04932173,  1.18740738,  1.32549303,  1.46357868,  1.60166433,
#          1.73974998,  1.87783563,  2.01592128,  2.15400692,  2.29209257,
#          2.43017822,  2.56826387,  2.70634952,  2.84443517,  2.98252082,
#          3.12060646,  3.25869211,  3.39677776,  3.53486341,  3.67294906,
#          3.81103471,  3.94912036,  4.08720601,  4.22529165,  4.3633773 ,
#          4.50146295,  4.6395486 ,  4.77763425,  4.9157199 ,  5.05380555,
#          5.19189119]),
#  <a list of 50 Patch objects>)

# %% [markdown]
# # image

# %%
# generationdes data ne pas comprendre ceci
x = np.cos(np.linspace(0, 4*np.pi, 1000))
y = np.sin(np.linspace(0, 4*np.pi, 1000))
X,Y = np.meshgrid(x,y)
data = Y*X

# attention interpolation
fig, ax = plt.subplots()
im = ax.imshow(data, cmap='hot', interpolation='nearest')
im.set_clim(-2, 2)
fig.colorbar(im, ax=ax)

# %% [markdown]
# # fill_between

# %%
fig, ax = plt.subplots()
x = np.arange(0,30, .1)
y1 = x**3
y2 = x**3.5
m = (y1 + y2)/2

ax.fill_between(x, y1, y2, color='y', alpha=.4)
ax.plot(x, m, color='k')

# %% [markdown]
# # excerice 7.3
#
# Générer 9 signaux sinusoidaux de frequence 5Hz entre 0 et 3.s.
# Chaque signal a niveau de bruit de plus en plus grand.
#
# Sur la figure 1 : Afficher chaque signal dans un subplot sur une grille
# Sur la figure 2 : afficher la moyenne et la std.

# %% [markdown]
# # Solution 7.3

# %%
sampling_rate = 1000.
freq = 5.
times = np.arange(0,3, 1./sampling_rate)

#generate data
sigs = []
for i in range(9):
    sig = np.sin(np.pi*2*freq*times)
    noise = np.random.randn(sig.size)*i*.5
    sig = sig + noise
    sigs.append(sig)

fig1, axs = plt.subplots(nrows=3, ncols=3)
#axs = axs.reshape(-1)
axs = axs.flatten()
for i, sig in enumerate(sigs):
    ax = axs[i]
    ax.plot(times, sig)

fig2, ax = plt.subplots()
tab_sigs = np.vstack(sigs)
m = np.mean(tab_sigs, axis=0)
s = np.std(tab_sigs, axis=0)
ax.plot(times, m, linewidth=2)
ax.fill_between(times, m-s, m+s, color='b', alpha=.4)
